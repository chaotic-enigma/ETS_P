# %%
import pandas as pd
import plotly.graph_objs as go
from plotly.offline import (download_plotlyjs, init_notebook_mode, plot, iplot)

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
eqdf = pd.read_csv('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_week.csv')
eqdf.shape
# Out:
# (2705, 22)

# %%
with open('map_token.txt', 'r') as mk:
    map_token = mk.read()

# %%
eqdf = eqdf[eqdf['mag'] >= 2]
eqdf.head()
# Out:
#                         time   latitude   longitude  depth   mag magType  \
# 6   2019-09-27T14:22:56.650Z  37.646500 -118.947166   4.84  2.27      md
# 13  2019-09-27T14:15:53.220Z  38.836334 -122.826668   2.15  2.32      md
# 14  2019-09-27T14:15:33.690Z  38.838665 -122.826500   2.12  2.92      md
# 15  2019-09-27T14:07:34.560Z  35.934000 -117.322500   2.79  2.36      ml
# 16  2019-09-27T14:02:06.154Z -30.040600 -177.896100  45.45  5.00      mb
#
#      nst   gap     dmin   rms  ...                   updated  \
# 6   21.0  65.0  0.02037  0.04  ...  2019-09-27T14:35:05.425Z
# 13  23.0  67.0  0.01473  0.02  ...  2019-09-27T14:26:09.294Z
# 14  51.0  59.0  0.01616  0.05  ...  2019-09-27T14:35:04.426Z
# 15  29.0  66.0  0.05345  0.15  ...  2019-09-27T14:18:05.000Z
# 16   NaN  92.0  0.79300  1.10  ...  2019-09-27T14:17:14.040Z
#
#                                   place        type horizontalError  \
# 6          3km ENE of Mammoth Lakes, CA  earthquake            0.40
# 13            9km NW of The Geysers, CA  earthquake            0.20
# 14            9km NW of The Geysers, CA  earthquake            0.15
# 15                20km NNE of Trona, CA  earthquake            0.23
# 16  85km S of Raoul Island, New Zealand  earthquake            8.20
#
#    depthError  magError  magNst     status  locationSource magSource
# 6        0.61     0.120    18.0  automatic              nc        nc
# 13       0.47     0.070     3.0  automatic              nc        nc
# 14       0.22     0.140    41.0  automatic              nc        nc
# 15       0.46     0.172    25.0  automatic              ci        ci
# 16       9.20     0.109    27.0   reviewed              us        us
#
# [5 rows x 22 columns]

# %%
eqdf.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
eqdf['type'].value_counts()
# Out:
# earthquake    731
# explosion       4
# Name: type, dtype: int64

# %%
cs_mag = [
    [0, '#a303b9'],	[0.25, '#ea6402'],[0.5, '#fa73a0'],	
    [0.75, '#f03b20'], [1, '#bd0026'],
]

# %%
latitudes = eqdf['latitude'].to_list()
longitudes = eqdf['longitude'].to_list()
magnitudes = eqdf['mag'].to_list()
depths = eqdf['depth'].to_list()
places = eqdf['place'].to_list()

# %%
center_lat = eqdf[eqdf['mag'] >= eqdf['mag'].max()]['latitude'].to_list()[0]
center_lon = eqdf[eqdf['mag'] >= eqdf['mag'].max()]['longitude'].to_list()[0]
print('Center latitude : {}, Center longitude : {}'.format(center_lat, center_lon))
# Out:
# Center latitude : -3.45, Center longitude : 128.3471

# %%
traces = go.Densitymapbox(
    lat=latitudes,
    lon=longitudes,
    z=magnitudes,
    radius=10,
    colorscale='Electric',
    showscale=True,
#     text=places,
#     hoverinfo='text'
)

# %%
trace_layout = go.Layout(
    height=500,
    autosize=True,
    showlegend=False,
    hovermode='closest',
    margin=dict(l=0, r=0, t=0, b=0),
    mapbox_style='stamen-terrain',
    mapbox=dict(
#         accesstoken=map_token,
        center=dict(
            lat=center_lat,
            lon=center_lon
        ),
    )
)

# %%
figure = dict(data=traces,
              layout=trace_layout
             )
iplot(figure)
# Out:
# <div>
#
#
#             <div id="abcd44bd-73c8-4c13-a9bd-70a97d7fc76f" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("abcd44bd-73c8-4c13-a9bd-70a97d7fc76f")) {
#                     Plotly.newPlot(
#                         'abcd44bd-73c8-4c13-a9bd-70a97d7fc76f',
#                         [{"colorscale": [[0.0, "rgb(0,0,0)"], [0.2, "rgb(30,0,100)"], [0.4, "rgb(120,0,100)"], [0.6, "rgb(160,90,0)"], [0.8, "rgb(230,200,0)"], [1.0, "rgb(255,250,220)"]], "lat": [37.646499600000006, 38.8363342, 38.838665, 35.934, -30.0406, 19.4178333, 19.1998, 19.0925, 19.22, -30.1309, 35.5341667, -23.1829, 38.8495, 68.9235, 37.8918, 57.9441, 38.8008347, 54.3171, 36.555833299999996, 59.7115, 53.4548, -21.1663, 19.0103, 19.0656, 58.4534, 35.28669357, 37.642166100000004, 36.771333299999995, -8.9151, 19.092, 35.6, 41.9882, -7.6741, -55.3567, -8.2456, 18.9013, -21.913, -25.7017, 45.6188333, 60.1285, 37.6409988, 37.6411667, 19.360332500000002, 30.5305, 18.7278, 61.5225, 19.2913342, 32.7516667, 18.9636, 37.6464, 19.185, 60.9221, 35.9488333, 36.5929985, 19.1415, 19.191833499999998, 19.102999999999998, 69.5352, -24.0717, 19.0783, 19.0038, 18.2255, 19.2191, -29.8605, 18.924, 40.8389, 19.099, 51.3663, 10.7786, -9.7326, -13.4442, 41.8461, 19.3435, 40.296833, 19.0336, 19.3673325, 19.065, 37.8593, 19.145500199999997, 36.5895004, 60.3329, -40.8109, 35.9388333, 35.1305, 38.821166999999996, 61.7325, 18.9831, 19.1441, 19.2136, 19.1153, 36.5888329, 19.169500399999997, -28.8, 28.0881, 28.0078, 69.0891, 19.0038, 36.585666700000004, 37.6394997, 68.8194, 19.4335003, 18.9678, 40.2056656, 60.9587, 19.1383, 40.8556, -7.2184, 40.89, 19.203, 18.9475, 19.1681671, 26.0579, 19.0275, 48.908, 19.2070007, -14.1076, 19.191833499999998, 62.7272, 19.241, 36.584999100000005, 35.6668333, 37.3929, 40.573001899999994, 19.3146, 19.2463, 69.4866, 19.1241, 33.1606, 38.6627, 19.3165, 19.1765, 19.0141, 19.273, 59.6846, 19.1548, 65.7827, 19.2121, 19.0801, -3.6627, 19.0546, 36.722167999999